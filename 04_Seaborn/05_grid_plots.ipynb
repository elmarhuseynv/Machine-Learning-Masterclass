# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
sns.catplot(df, x='gender', y = 'math score',kind = 'box', col='lunch', row ='test preparation course')

# %%
sns.catplot(df, x='gender', y = 'math score',kind = 'box', col='lunch', row ='race/ethnicity')

# %%
#sns.catplot(df, x='gender', y = 'math score',kind = 'box', col='lunch', row ='race/ethnicity')

# %%
g = sns.PairGrid(df, hue = 'gender')

g = g.map_upper(sns.scatterplot)

g = g.map_diag(sns.kdeplot)

g = g.map_lower(sns.kdeplot)

g = g.add_legend()
